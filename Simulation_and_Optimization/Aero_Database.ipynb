# %% [markdown]
# # Read in CFD Data

# %% [markdown]
# Build interpolation space in variables using [interpolate](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html).

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
matrix = []
Dict = {}

with open('aero_database_demo.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for item in csv_reader:
        matrix.append(item)
    for k in range(len(matrix[0])):
        values = []
        for j in range(len(matrix)-1):
            value = float(matrix[j+1][k].strip())
            values.append(value)
        key = matrix[0][k].strip()
        Dict.update({key: values})

# %%
variables = Dict.keys()
print(variables)
# Out:
# dict_keys(['Mach', 'qbar', 'pitch', 'yaw', 'roll', 'Cx', 'Cy', 'Cz', 'Cl', 'Cm', 'Cn'])

# %% [markdown]
# ### Mach

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Mach']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### qbar

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['qbar']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### pitch

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['pitch']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### yaw

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['yaw']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### roll

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['roll']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cx

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cx']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cy

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cy']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cz

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cz']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cl

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cl']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cm

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cm']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %% [markdown]
# ### Cn

# %%
x = np.arange(0, len(matrix)-1)
xnew = np.arange(0, (len(matrix)-2), 1e-7)
y = Dict['Cn']
f = interpolate.interp1d(x, y, kind = 'cubic')
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()
